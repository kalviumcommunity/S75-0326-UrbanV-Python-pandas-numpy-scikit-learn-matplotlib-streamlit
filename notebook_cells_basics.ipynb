# %% [markdown]
# # Understanding Code vs Markdown

# %% [markdown]
# This notebook demonstrates the difference between Code cells and Markdown cells in Jupyter Notebook.

# %%
print("Hello, Jupyter")

# %% [markdown]
# This code prints a simple message to verify that the Code cell executes Python statements.
